# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

from billApplication.model.camera import _getMask, _cornerPoints, _transformImg

# %%
img = cv2.imread("data/webcam4.jpg")
#img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)
plt.show()

# %%
'''main function to retrieve the bill'''
mask = _getMask(frame=img)
# plt.imshow(mask)
# plt.show()
corners = _cornerPoints(bw = mask)
print(f"Number of corners = {len(corners)}")
print(corners)
# Out:
# Number of corners = 4
# [[[220  43]]
#
#  [[205 434]]
#
#  [[515 432]]
#
#  [[477  48]]]

# %%
bill = _transformImg(frame=img, corners=corners)
plt.imshow(bill)
plt.show()
